# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

df = pd.read_csv('BostonHousing.csv')
df.head(n=10)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# 5  394.12   5.21  28.7
# 6  395.60  12.43  22.9
# 7  396.90  19.15  27.1
# 8  386.63  29.93  16.5
# 9  386.71  17.10  18.9

# %%
# df.drop(columns=['CAT. MEDV'],inplace=True)
# df.dropna(inplace=True)
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.corr()['medv'].sort_values()
# Out:
# lstat     -0.737663
# ptratio   -0.507787
# indus     -0.483725
# tax       -0.468536
# nox       -0.427321
# crim      -0.388305
# rad       -0.381626
# age       -0.376955
# chas       0.175260
# dis        0.249929
# b          0.333461
# zn         0.360445
# rm         0.695360
# medv       1.000000
# Name: medv, dtype: float64

# %%
X = df.loc[:, df.columns != 'medv'].values  #or X = df.loc[:,['lstat','ptratio','rm]]
y = df.loc[:, df.columns == 'medv'].values  #or y = df.loc[:,'medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=45)

# %% [markdown]
# ### Normalizing Training and Testing Data Set

# %%
scaler = StandardScaler() #standardise (Z-score normalization => mean = 0 and Std = 1)
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ##### input_shape=(13,): This parameter defines the shape of the input data for the first layer. In this case, it expects input data with 13 features.
# ##### activation='relu': This parameter specifies the activation function to be used in the layer. Activation functions introduce non-linearity to the network, enabling it to learn complex patterns. In this case, the Rectified Linear Unit (ReLU) activation function is used, which returns the input if it is positive and 0 otherwise.
# ##### optimizer='adam': This parameter specifies the optimization algorithm used during training. Adam (Adaptive Moment Estimation) is a popular optimization algorithm known for its efficiency and effectiveness in a wide range of deep learning tasks.
#
# ##### loss='mse': This parameter defines the loss function used to measure the difference between the predicted output and the true output during training. MSE (Mean Squared Error) is a common loss function for regression tasks that calculates the average squared difference between the predicted and true values.
#
# ##### metrics=['mae']: This parameter specifies the evaluation metric(s) used to monitor the model's performance during training. MAE (Mean Absolute Error) is a metric that measures the average absolute difference between the predicted and true values. It provides a measure of the model's accuracy.

# %% [markdown]
# ``` Adam optimizer dynamically adjusts the learning rates for individual parameters in a neural network based on the history of gradients. This adaptive learning rate strategy helps improve the efficiency and robustness of the optimization process during training. ```

# %%
model = Sequential(layers=[Dense(128, input_shape=(13, ), activation='relu', name='dense_1'),Dense(64, activation='relu', name='dense_2'),Dense(1, activation='linear', name='dense_output')])


# model.add(Dense(128, input_shape=(13, ), activation='relu', name='dense_1'))
# model.add(Dense(64, activation='relu', name='dense_2'))
# model.add(Dense(1, activation='linear', name='dense_output'))

model.compile(optimizer='adam', loss='mse',metrics=['mae'])
model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_output (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,113 (39.50 KB)
#  Trainable params: 10,113 (39.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, epochs=100, validation_split=0.05, verbose = 'auto')
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 580.6482 - mae: 22.4042 - val_loss: 434.7552 - val_mae: 18.1077
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 519.7395 - mae: 21.0075 - val_loss: 372.4650 - val_mae: 16.2166
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 439.9804 - mae: 19.0742 - val_loss: 290.7426 - val_mae: 13.7697
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 323.2358 - mae: 16.0030 - val_loss: 200.2167 - val_mae: 11.0994
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 194.9606 - mae: 11.6641 - val_loss: 134.9404 - val_mae: 9.0443
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 104.8249 - mae: 7.9808 - val_loss: 114.4461 - val_mae: 9.2571
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 71.2145 - mae: 6.4150 - val_loss: 91.1026 - val_mae: 8.1362
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53.4905 - mae: 5.3704 - val_loss: 57.2687 - val_mae: 6.4832
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.8307 - mae: 4.4983 - val_loss: 36.7544 - val_mae: 5.1223
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.5139 - mae: 3.9735 - val_loss: 26.1540 - val_mae: 4.1819
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.5342 - mae: 3.6788 - val_loss: 20.9610 - val_mae: 3.6941
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.2286 - mae: 3.5298 - val_loss: 16.7175 - val_mae: 3.3033
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.0831 - mae: 3.3280 - val_loss: 12.7561 - val_mae: 2.8426
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.8939 - mae: 3.2044 - val_loss: 11.4758 - val_mae: 2.7002
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.7297 - mae: 3.1032 - val_loss: 9.9403 - val_mae: 2.4927
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.9504 - mae: 3.0516 - val_loss: 8.7860 - val_mae: 2.3800
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8749 - mae: 2.0684 - val_loss: 4.8804 - val_mae: 1.6478
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8242 - mae: 2.0635 - val_loss: 4.7616 - val_mae: 1.6018
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8375 - mae: 2.0604 - val_loss: 5.0828 - val_mae: 1.6770
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7534 - mae: 2.0662 - val_loss: 4.1735 - val_mae: 1.5207
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8304 - mae: 2.0848 - val_loss: 4.3612 - val_mae: 1.5629
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7245 - mae: 2.0735 - val_loss: 4.9239 - val_mae: 1.7132
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6069 - mae: 2.0717 - val_loss: 4.6000 - val_mae: 1.6257
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4490 - mae: 2.0503 - val_loss: 5.0097 - val_mae: 1.7327
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4392 - mae: 2.0417 - val_loss: 4.7975 - val_mae: 1.6642
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3931 - mae: 2.0552 - val_loss: 4.9707 - val_mae: 1.6989
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3233 - mae: 2.0570 - val_loss: 6.0423 - val_mae: 1.7647
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2888 - mae: 2.0394 - val_loss: 5.3898 - val_mae: 1.6759
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0629 - mae: 1.9961 - val_loss: 5.3757 - val_mae: 1.7605
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0422 - mae: 1.9751 - val_loss: 5.4065 - val_mae: 1.8227
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9385 - mae: 1.9719 - val_loss: 4.5507 - val_mae: 1.5962
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7642 - mae: 1.9589 - val_loss: 5.4984 - val_mae: 1.8070
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8206 - mae: 1.9576 - val_loss: 5.2521 - val_mae: 1.7801
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6812 - mae: 1.9423 - val_loss: 4.7967 - val_mae: 1.6713
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6647 - mae: 1.9516 - val_loss: 4.8600 - val_mae: 1.6675
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7149 - mae: 1.9582 - val_loss: 5.1216 - val_mae: 1.7493
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5626 - mae: 1.9289 - val_loss: 5.0671 - val_mae: 1.7446
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6650 - mae: 1.9459 - val_loss: 4.4821 - val_mae: 1.7035
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4542 - mae: 1.9227 - val_loss: 4.6147 - val_mae: 1.7171
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4165 - mae: 1.9277 - val_loss: 5.1583 - val_mae: 1.7724
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3878 - mae: 1.9165 - val_loss: 4.8383 - val_mae: 1.6895
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3069 - mae: 1.8974 - val_loss: 5.2500 - val_mae: 1.8325
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2665 - mae: 1.8941 - val_loss: 4.6699 - val_mae: 1.6691
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1505 - mae: 1.8948 - val_loss: 5.1059 - val_mae: 1.7518
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1399 - mae: 1.8860 - val_loss: 5.2387 - val_mae: 1.7969
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0857 - mae: 1.8816 - val_loss: 5.3076 - val_mae: 1.7650
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0761 - mae: 1.8819 - val_loss: 5.2182 - val_mae: 1.7360
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9708 - mae: 1.8678 - val_loss: 5.4021 - val_mae: 1.8359
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9835 - mae: 1.8648 - val_loss: 5.1557 - val_mae: 1.8234
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9192 - mae: 1.8529 - val_loss: 4.6341 - val_mae: 1.7316
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9719 - mae: 1.8393 - val_loss: 5.2594 - val_mae: 1.8326
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0165 - mae: 1.8828 - val_loss: 4.8927 - val_mae: 1.7281
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7310 - mae: 1.8263 - val_loss: 4.9994 - val_mae: 1.8290
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7272 - mae: 1.8427 - val_loss: 4.7938 - val_mae: 1.7605
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7008 - mae: 1.8349 - val_loss: 4.3202 - val_mae: 1.6727

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(X_test)
mse_nn, mae_nn= model.evaluate(X_test, y_test)
r2 = r2_score(y_test, y_pred)

print('Mean squared error on test data: ', mse_nn)
print('Mean absolute error on test data: ', mae_nn)
print('Accuracy:', r2*100)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.3825 - mae: 2.7503
# Mean squared error on test data:  14.38253402709961
# Mean absolute error on test data:  2.7502799034118652
# Accuracy: 85.80583011804904

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred, c='green')

p1 = max(max(y_pred), max(y_test))
p2 = min(min(y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()
